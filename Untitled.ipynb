# %%
from bs4 import BeautifulSoup
import requests
import json
import time
import random
import numpy as np
import pandas as pd

# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.37'})
rows = []
#loop through max price, if price < current max price, break and reduce
#set min price, sort lowest first, go through all 400, -> set min price at around 400 page, go through all 400 ->s 

min_prices = ["50000", "300000", "350000", "400000", ""]
for search in :
    n_page = 0
    
    


    for page in range(0,402):
        n_page += 1

        price_bracket = 

        #search_url = "https://www.zoopla.co.uk/for-sale/property/london/brixton/?include_sold=true&is_auction=false&is_retirement_home=false&is_shared_ownership=false&page_size=25&q=Brixton%2C%20London&radius=1&results_sort=newest_listings&search_source=refine" + "&pn" + str(page)
        #search_url = "https://www.zoopla.co.uk/for-sale/property/london/?include_sold=true&is_auction=false&is_retirement_home=false&is_shared_ownership=false&page_size=25&q=London&radius=0&results_sort=newest_listings&search_source=refine" + "&pn" + str(page)
        search_url = f"https://www.zoopla.co.uk/for-sale/property/london/?include_sold=true&is_auction=false&is_retirement_home=false&is_shared_ownership=false&price_min=50000&q=London&radius=0&results_sort=lowest_price&search_source=facets" + "&pn" + str(page)

        #search_url =  "https://www.zoopla.co.uk"

        response = requests.get(search_url, headers=headers)
        #response = requests.get(search_url, headers={'User-Agent': 'Mozilla/5.0'})
        search_html = BeautifulSoup(response.text, 'html5lib')

        #print(response)

        search_house_containers = search_html.find_all('div', class_='earci3d1 css-tk5q7b-Wrapper-ListingCard-StyledListingCard e2uk8e10')

        house_urls = []
        time.sleep(random.randint(1, 4))

        if search_house_containers != []:
            for container in search_house_containers:
                url_suffix = container.a['href'].split('?')[0]
                if len(url_suffix) == 27:
                    house_urls.append("https://www.zoopla.co.uk" + url_suffix)
        else:
            print("No Houses on page")
            break
        #print("house urls = " + house_urls)

        count = 0
        for house_url in house_urls:
            try:
                house_response = requests.get(house_url, headers=headers)
                house_html = BeautifulSoup(house_response.text, 'html5lib')
                house_details = house_html.find('script', id='__NEXT_DATA__')

                details_dict = json.loads(house_details.text)

                specific_info = details_dict['props']['initialProps']['pageProps']['data']['listing']['adTargeting']

                rows.append(specific_info)
                count += 1

                time.sleep(random.randint(1, 3))
                #print("Next house")
            except:
                print("error on this one " + house_url)

        print("Next Page, finished page " + str(n_page))
        print(str(count) + " Houses on that page")
    
    
    
print('You scraped {} pages containing {} properties.'.format(n_page, len(rows)))
# Out:
# Next Page, finished page 1
# 22 Houses on that page
# error on this one https://www.zoopla.co.uk/for-sale/details/58431866/
# Next Page, finished page 2
# 21 Houses on that page
# error on this one https://www.zoopla.co.uk/for-sale/details/58431913/
# error on this one https://www.zoopla.co.uk/for-sale/details/58431907/
# Next Page, finished page 3
# 20 Houses on that page
# Next Page, finished page 4
# 21 Houses on that page
# Next Page, finished page 5
# 21 Houses on that page
# error on this one https://www.zoopla.co.uk/for-sale/details/51753333/
# Next Page, finished page 6
# 21 Houses on that page
# Next Page, finished page 7
# 23 Houses on that page
# Next Page, finished page 8
# 23 Houses on that page
# Next Page, finished page 9
# 23 Houses on that page
# Next Page, finished page 10
# 23 Houses on that page
# Next Page, finished page 11
# 23 Houses on that page
# error on this one https://www.zoopla.co.uk/for-sale/details/58432181/
# Next Page, finished page 12
# 22 Houses on that page
# Next Page, finished page 13
# 23 Houses on that page
# Next Page, finished page 14
# 23 Houses on that page
# Next Page, finished page 15
# 23 Houses on that page
# error on this one https://www.zoopla.co.uk/for-sale/details/58432308/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432309/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432295/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432274/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432258/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432263/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432229/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432220/
# error on this one https://www.zoopla.co.uk/for-sale/details/55362812/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432226/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432208/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432204/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432183/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432181/
# error on this one https://www.zoopla.co.uk/for-sale/details/53978678/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432176/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432161/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432094/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432095/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432097/
# error on this one https://www.zoopla.co.uk/for-sale/details/58432092/
# Next Page, finished page 16
# 3 Houses on that page
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-34-d07bc2ec3ae0>", line 14, in <module>
#     response = requests.get(search_url, headers=headers)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\requests\api.py", line 76, in get
#     return request('get', url, params=params, **kwargs)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\requests\api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\urllib3\connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\urllib3\connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\urllib3\connection.py", line 411, in connect
#     self.sock = ssl_wrap_socket(
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\urllib3\util\ssl_.py", line 428, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\urllib3\util\ssl_.py", line 472, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\inspect.py", line 752, in getmodule
#     f = getabsfile(module)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\inspect.py", line 721, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\inspect.py", line 706, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2063, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1079, in format_exception_as_a_whole
#     records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1116, in get_records
#     traceback.print_exc(file=self.ostream)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 163, in print_exc
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 103, in print_exception
#     for line in TracebackException(
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 508, in __init__
#     self.stack = StackSummary.extract(
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 366, in extract
#     f.line
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 288, in line
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\linecache.py", line 93, in updatecache
#     stat = os.stat(fullname)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 3454, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2076, in showtraceback
#     print('\n' + self.get_exception_only(), file=sys.stderr)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2021, in get_exception_only
#     msg = traceback.format_exception_only(etype, value)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 140, in format_exception_only
#     return list(TracebackException(etype, value, None).format_exception_only())
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 524, in __init__
#     self._load_lines()
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 536, in _load_lines
#     self.__context__._load_lines()
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 536, in _load_lines
#     self.__context__._load_lines()
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 536, in _load_lines
#     self.__context__._load_lines()
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 534, in _load_lines
#     frame.line
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\traceback.py", line 288, in line
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\linecache.py", line 93, in updatecache
#     stat = os.stat(fullname)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\rob-k\anaconda3\envs\ml\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
# KeyboardInterrupt

# %%
df = pd.DataFrame(rows)

# %%
df.tail()
# Out:
#                     __typename  acorn  acornType areaName  bedsMax  bedsMin  \
# 4291  ListingAnalyticsTaxonomy   15.0       15.0   London        2        2
# 4292  ListingAnalyticsTaxonomy   15.0       15.0   London        1        1
# 4293  ListingAnalyticsTaxonomy   16.0       16.0   London        3        3
# 4294  ListingAnalyticsTaxonomy   20.0       20.0   London        2        2
# 4295  ListingAnalyticsTaxonomy   17.0       17.0   London        1        1
#
#       branchId                                      branchLogoUrl  \
# 4291     80795  https://st.zoocdn.com/zoopla_static_agent_logo...
# 4292      9539  https://st.zoocdn.com/zoopla_static_agent_logo...
# 4293    101641  https://st.zoocdn.com/zoopla_static_agent_logo...
# 4294      8169  https://st.zoocdn.com/zoopla_static_agent_logo...
# 4295     58933  https://st.zoocdn.com/zoopla_static_agent_logo...
#
#                                           branchName     brandName  ...  \
# 4291                              Foxtons - Vauxhall       Foxtons  ...
# 4292  riverhomes, South West & Central London office    riverhomes  ...
# 4293                    Winkworth - Kennington Sales     Winkworth  ...
# 4294                             Winkworth - Dulwich     Winkworth  ...
# 4295                       Purplebricks, Head Office  Purplebricks  ...
#
#       priceMax  priceMin priceQualifier propertyHighlight propertyType  \
# 4291    475000    475000                                          flat
# 4292    275000    250000                                     houseboat
# 4293   1400000   1300000                                      terraced
# 4294    700000    700000                                      terraced
# 4295    450000    425000    guide_price                           flat
#
#      regionName   section  sizeSqFeet     tenure    zindex
# 4291     London  for-sale                   None  465263.0
# 4292     London  for-sale                   None       NaN
# 4293     London  for-sale               freehold  719209.0
# 4294     London  for-sale              leasehold  735798.0
# 4295     London  for-sale               freehold  418797.0
#
# [5 rows x 48 columns]

# %%
df.to_csv('brixton_data.csv')

# %%
len(search_house_containers[5].a['href'].split('?')[0])
# Out:
# 28

# %%
details_dict
# Out:
# {'props': {'initialProps': {'pageProps': {'listingId': 58426277,
#     'data': {'listing': {'__typename': 'ListingData',
#       'branch': {'__typename': 'AgentBranch',
#        'address': '1-5 Wandsworth Road, London',
#        'branchDetailsUri': '/find-agents/branch/foxtons-vauxhall-london-80795/',
#        'branchResultsUri': '/for-sale/branch/foxtons-vauxhall-london-80795/',
#        'logoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(592983).png',
#        'phone': '020 8033 9116',
#        'name': 'Foxtons - Vauxhall',
#        'postcode': 'SW8 2LN',
#        'memberType': 'agent'},
#       'epc': None,
#       'floorPlan': {'__typename': 'FloorPlan',
#        'image': [{'__typename': 'Media',
#          'filename': '992b69fa387bfc9bb7610321ee17467fc873d072.png',
#          'caption': 'Floorplan - Representation Of Current Layout, Internal Floor Area Approx.'}],
#        'links': None,
#        'pdf': None},
#       'administrationFees': None,
#       'embeddedContent': {'__typename': 'EmbeddedContent',
#        'videos': None,
#        'tours': None,
#        'smartViewings': None},
#       'listingUris': {'__typename': 'ListingUris',
#        'detail': '/for-sale/details/58426277/'},
#       'section': 'for-sale',
#       'marketStats': {'__typename': 'MarketStats',
#        'areaName': 'SE17',
#        'areaNameUri': 'london/se17/walworth-elephant-and-castle',
#        'askingPrices': {'__typename': 'AskingPrices',
#         'toRent': {'__typename': 'AskingPrice',
#          'meanValue': 1936.9999999999998}},
#        'historicalEstimates': [{'__typename': 'HistoricalEstimate',
#          'date': '2021-04-27',
#          'overMonth': '0',
#          'value': 548834,
#          'pctChangeSince': 0,
#          'changeSince': 0},
#         {'__typename': 'HistoricalEstimate',
#          'date': '2021-01-27',
#          'overMonth': '3',
#          'value': 540548,
#          'pctChangeSince': 1.533,
#          'changeSince': 8286},
#         {'__typename': 'HistoricalEstimate',
#          'date': '2020-10-27',
#          'overMonth': '6',
#          'value': 537145,
#          'pctChangeSince': 2.176,
#          'changeSince': 11689},
#         {'__typename': 'HistoricalEstimate',
#          'date': '2020-04-27',
#          'overMonth': '12',
#          'value': 521722,
#          'pctChangeSince': 5.197,
#          'changeSince': 27112},
#         {'__typename': 'HistoricalEstimate',
#          'date': '2016-04-27',
#          'overMonth': '60',
#          'value': 512227,
#          'pctChangeSince': 7.147,
#          'changeSince': 36607},
#         {'__typename': 'HistoricalEstimate',
#          'date': '2011-04-27',
#          'overMonth': '120',
#          'value': 324974,
#          'pctChangeSince': 68.886,
#          'changeSince': 223860},
#         {'__typename': 'HistoricalEstimate',
#          'date': '2006-04-27',
#          'overMonth': '180',
#          'value': 299953,
#          'pctChangeSince': 82.973,
#          'changeSince': 248881},
#         {'__typename': 'HistoricalEstimate',
#          'date': '2001-04-27',
#          'overMonth': '240',
#          'value': 173645,
#          'pctChangeSince': 216.067,
#          'changeSince': 375189}],
#        'sales': [{'__typename': 'HistoricalSales',
#          'mean': 451953,
#          'overYear': '1',
#          'newBuilds': 8,
#          'numSales': 57},
#         {'__typename': 'HistoricalSales',
#          'mean': 485329,
#          'overYear': '3',
#          'newBuilds': 83,
#          'numSales': 324},
#         {'__typename': 'HistoricalSales',
#          'mean': 495083,
#          'overYear': '5',
#          'newBuilds': 222,
#          'numSales': 782},
#         {'__typename': 'HistoricalSales',
#          'mean': 453421,
#          'overYear': '7',
#          'newBuilds': 351,
#          'numSales': 1249}],
#        'recentSales': [{'__typename': 'RecentSale',
#          'date': '2021-02-03T00:00:00Z',
#          'price': 799999,
#          'propertyId': 33116934,
#          'streetAddress': 'Flat 5, 3 Danson Mews',
#          'uri': 'flat-5/3-danson-mews/london/se17-3fn'},
#         {'__typename': 'RecentSale',
#          'date': '2020-12-22T00:00:00Z',
#          'price': 460000,
#          'propertyId': 21106463,
#          'streetAddress': '7 Lytham Street',
#          'uri': '7-lytham-street/london/se17-2pn'},
#         {'__typename': 'RecentSale',
#          'date': '2020-12-18T00:00:00Z',
#          'price': 420000,
#          'propertyId': 21104543,
#          'streetAddress': '7 Aylesbury Road',
#          'uri': '7-aylesbury-road/london/se17-2eq'},
#         {'__typename': 'RecentSale',
#          'date': '2020-12-18T00:00:00Z',
#          'price': 730000,
#          'propertyId': 21109785,
#          'streetAddress': '28 Fielding Street',
#          'uri': '28-fielding-street/london/se17-3hd'},
#         {'__typename': 'RecentSale',
#          'date': '2020-12-17T00:00:00Z',
#          'price': 615000,
#          'propertyId': 21106872,
#          'streetAddress': '94 Mina Road',
#          'uri': '94-mina-road/london/se17-2qs'}],
#        'propertyTypeGroup': 'flat'},
#       'adTargeting': {'__typename': 'ListingAnalyticsTaxonomy',
#        'acorn': 15,
#        'acornType': 15,
#        'areaName': 'London',
#        'bedsMax': 2,
#        'bedsMin': 2,
#        'branchId': 80795,
#        'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(592983).png',
#        'branchName': 'Foxtons - Vauxhall',
#        'brandName': 'Foxtons',
#        'chainFree': False,
#        'companyId': 1370,
#        'countryCode': 'gb',
#        'countyAreaName': 'London',
#        'currencyCode': 'GBP',
#        'displayAddress': 'Latvia Court, Walworth, London SE17',
#        'furnishedState': '',
#        'groupId': None,
#        'hasEpc': False,
#        'hasFloorplan': True,
#        'incode': '3HB',
#        'isRetirementHome': False,
#        'isSharedOwnership': False,
#        'listingCondition': 'pre-owned',
#        'listingId': 58426277,
#        'listingsCategory': 'residential',
#        'listingStatus': 'for_sale',
#        'location': 'London',
#        'memberType': 'agent',
#        'numBaths': 1,
#        'numBeds': 2,
#        'numImages': 11,
#        'numRecepts': 1,
#        'outcode': 'SE17',
#        'postalArea': 'SE',
#        'postTownName': 'London',
#        'priceActual': 475000,
#        'price': 475000,
#        'priceMax': 475000,
#        'priceMin': 475000,
#        'priceQualifier': '',
#        'propertyHighlight': '',
#        'propertyType': 'flat',
#        'regionName': 'London',
#        'section': 'for-sale',
#        'sizeSqFeet': '',
#        'tenure': None,
#        'zindex': 465263},
#       'detailedDescription': 'Set within a secure gated community, this well presented 2 bedroom garden apartment boasts 2 double bedrooms, a smart reception with space to dine and a charming private Garden.<br><br>Latvia Court is a secure gated development offering easy access to the many local shops and eateries available along Walworth Road while Elephant and Castle offers an abundance of eclectic eateries and transport links for easy access to the City.',
#       'features': {'__typename': 'Features',
#        'bullets': ['Good size reception with space to dine',
#         'Modern open plan kitchen with appliances',
#         'Main bedroom with fitted wardrobes',
#         '2nd double bedroom',
#         'Family bathroom',
#         'Additional storage to entrance',
#         'Charming private garden',
#         'Quietly set back from the main road'],
#        'flags': None,
#        'highlights': None},
#       'propertyImage': [{'__typename': 'Media',
#         'filename': '6f0ea6dc1c1db3af8f26050722c8ef20e5277aeb.jpg',
#         'caption': None},
#        {'__typename': 'Media',
#         'filename': 'fd83059f43817f2596e0203bedae9bb273ea152d.jpg',
#         'caption': None},
#        {'__typename': 'Media',
#         'filename': '715fa52217fdafe164a6b38682cc0caecbf5196d.jpg',
#         'caption': None},
#        {'__typename': 'Media',
#         'filename': 'cbb676a2a518d74b0dcb8d061e53342835449abe.jpg',
#         'caption': None},
#        {'__typename': 'Media',
#         'filename': 'e19f800e59779848d26d9f1e211c1693eee4a59b.jpg',
#         'caption': None},
#        {'__typename': 'Media',
#         'filename': '5c2e544fcc2115c2d074b694b143c8ce2b5da568.jpg',
#         'caption': None},
#        {'__typename': 'Media',
#         'filename': '0aa0418e97c0a73696a450bfa39eef82e49f5a5c.jpg',
#         'caption': None},
#        {'__typename': 'Media',
#         'filename': 'e82423b2f044af60fe7d778d66ad066fbef9cf34.jpg',
#         'caption': None},
#        {'__typename': 'Media',
#         'filename': '7cd4c4d54675b10e8d8ad0b7495a80a7f6075942.jpg',
#         'caption': None},
#        {'__typename': 'Media',
#         'filename': 'c912c0499fd8da987a229fb0f7c813e8e76e3e46.jpg',
#         'caption': None},
#        {'__typename': 'Media',
#         'filename': 'ee209c6a1d5df1c436e66c4aa4c555980f1aad32.jpg',
#         'caption': None}],
#       'analyticsTaxonomy': {'__typename': 'ListingAnalyticsTaxonomy',
#        'location': 'London',
#        'regionName': 'London',
#        'section': 'for-sale',
#        'acorn': 15,
#        'acornType': 15,
#        'areaName': 'London',
#        'bedsMax': 2,
#        'bedsMin': 2,
#        'branchId': 80795,
#        'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(592983).png',
#        'branchName': 'Foxtons - Vauxhall',
#        'brandName': 'Foxtons',
#        'chainFree': False,
#        'companyId': 1370,
#        'countryCode': 'gb',
#        'countyAreaName': 'London',
#        'currencyCode': 'GBP',
#        'displayAddress': 'Latvia Court, Walworth, London SE17',
#        'furnishedState': '',
#        'groupId': None,
#        'hasEpc': False,
#        'hasFloorplan': True,
#        'incode': '3HB',
#        'isRetirementHome': False,
#        'isSharedOwnership': False,
#        'listingCondition': 'pre-owned',
#        'listingId': 58426277,
#        'listingsCategory': 'residential',
#        'listingStatus': 'for_sale',
#        'memberType': 'agent',
#        'numBaths': 1,
#        'numBeds': 2,
#        'numImages': 11,
#        'numRecepts': 1,
#        'outcode': 'SE17',
#        'postalArea': 'SE',
#        'postTownName': 'London',
#        'priceActual': 475000,
#        'price': 475000,
#        'priceMax': 475000,
#        'priceMin': 475000,
#        'priceQualifier': '',
#        'propertyHighlight': '',
#        'propertyType': 'flat',
#        'sizeSqFeet': '',
#        'tenure': None,
#        'zindex': 465263},
#       'metaTitle': '2 bed flat for sale in Latvia Court, Walworth, London SE17 - Zoopla',
#       'metaDescription': '2 bed flat for sale in Latvia Court, Walworth, London SE17, selling for £475,000 from Foxtons - Vauxhall. See property details on Zoopla or browse all our range of properties in Latvia Court, Walworth, London SE17.',
#       'location': {'__typename': 'ListingLocation',
#        'coordinates': {'__typename': 'LocationCoordinates',
#         'latitude': 51.485397,
#         'longitude': -0.095294}},
#       'content': {'__typename': 'MediaContent',
#        'floorPlan': [{'__typename': 'Media',
#          'original': 'https://lc.zoocdn.com/992b69fa387bfc9bb7610321ee17467fc873d072.png'}]},
#       'listingId': '58426277',
#       'title': '2 bed flat for sale',
#       'displayAddress': 'Latvia Court, Walworth, London SE17',
#       'statusSummary': {'__typename': 'ListingStatusSummary',
#        'label': 'Just added'},
#       'tags': None,
#       'counts': {'__typename': 'RoomCount',
#        'numBedrooms': 2,
#        'numBathrooms': 1,
#        'numLivingRooms': 1},
#       'floorArea': None,
#       'pricing': {'__typename': 'ListingPricing',
#        'qualifier': None,
#        'internalValue': 475000,
#        'rentFrequencyLabel': None,
#        'pricePerFloorAreaUnit': None,
#        'alternateRentFrequencyPrice': None},
#       'analyticsEcommerce': {'__typename': 'ListingAnalyticsEcommerce',
#        'brand': 'Foxtons',
#        'category': 'for-sale/resi/agent/pre-owned/gb',
#        'id': 58426277,
#        'name': 'FS_Contact',
#        'price': 1,
#        'quantity': 1,
#        'variant': 'standard'},
#       'additionalLinks': [{'__typename': 'Media',
#         'caption': 'Floorplan',
#         'original': 'https://www.foxtons.co.uk/properties-for-sale/se17/chpk1150209/large_floorplan',
#         'type': 'brochure'},
#        {'__typename': 'Media',
#         'caption': 'Property Details And Epcs',
#         'original': 'https://www.foxtons.co.uk/properties-for-sale/se17/chpk1150209',
#         'type': 'brochure'},
#        {'__typename': 'Media',
#         'caption': 'Super Sized Images',
#         'original': 'https://www.foxtons.co.uk/properties-for-sale/se17/chpk1150209/slide_large',
#         'type': 'brochure'}],
#       'pointsOfInterest': [{'__typename': 'PointOfInterest',
#         'title': "St Peter's Church of England Primary School",
#         'type': 'uk_school_primary',
#         'distanceMiles': 0.1},
#        {'__typename': 'PointOfInterest',
#         'title': "St Paul's Church of England Primary School, Walworth",
#         'type': 'uk_school_primary',
#         'distanceMiles': 0.2},
#        {'__typename': 'PointOfInterest',
#         'title': 'Kennington',
#         'type': 'london_underground_station',
#         'distanceMiles': 0.5},
#        {'__typename': 'PointOfInterest',
#         'title': 'Elephant & Castle',
#         'type': 'national_rail_station',
#         'distanceMiles': 0.6}],
#       'priceHistory': {'__typename': 'PriceHistory',
#        'firstPublished': {'__typename': 'PriceHistoryFirstPublished',
#         'firstPublishedDate': '2021-04-28 00:26:06',
#         'priceLabel': '£475,000'},
#        'lastSale': None,
#        'priceChanges': None},
#       'viewCount': {'__typename': 'ViewCount', 'viewCount30day': 0}},
#      'backToResultsLink': {'__typename': 'BackToResultsLink',
#       'linkType': 'geo',
#       'uri': '/for-sale/property/london/kennington/'},
#      'breadcrumbs': [{'__typename': 'Breadcrumbs',
#        'label': 'Zoopla',
#        'tracking': 'home',
#        'uri': '/',
#        'noAppend': None,
#        'i18nLabelKey': None},
#       {'__typename': 'Breadcrumbs',
#        'label': 'For sale',
#        'tracking': 'for sale',
#        'uri': '/for-sale/',
#        'noAppend': None,
#        'i18nLabelKey': None},
#       {'__typename': 'Breadcrumbs',
#        'label': 'London',
#        'tracking': 'london',
#        'uri': '/for-sale/property/london/',
#        'noAppend': None,
#        'i18nLabelKey': None},
#       {'__typename': 'Breadcrumbs',
#        'label': 'South London',
#        'tracking': 'south london',
#        'uri': '/for-sale/property/south-london/',
#        'noAppend': None,
#        'i18nLabelKey': None},
#       {'__typename': 'Breadcrumbs',
#        'label': 'Kennington',
#        'tracking': 'kennington',
#        'uri': '/for-sale/property/london/kennington/',
#        'noAppend': None,
#        'i18nLabelKey': None},
#       {'__typename': 'Breadcrumbs',
#        'label': 'Macleod Street',
#        'tracking': 'macleod street',
#        'uri': '/for-sale/property/london/macleod-street/',
#        'noAppend': None,
#        'i18nLabelKey': None},
#       {'__typename': 'Breadcrumbs',
#        'label': '2 bed flat for sale',
#        'tracking': None,
#        'uri': None,
#        'noAppend': 1,
#        'i18nLabelKey': None}]},
#     'mobileOS': None,
#     'apolloState': {},
#     'apollo': None,
#     'optimizelyDatafile': '{"version": "4", "rollouts": [{"experiments": [{"status": "Running", "audienceIds": [], "variations": [{"variables": [], "id": "19335511376", "key": "19335511376", "featureEnabled": true}], "id": "19336191273", "key": "19336191273", "layerId": "19328761035", "trafficAllocation": [], "forcedVariations": {}}], "id": "19328761035"}, {"experiments": [{"status": "Running", "audienceIds": [], "variations": [{"variables": [], "id": "19874710139", "key": "19874710139", "featureEnabled": true}], "id": "19877930660", "key": "19877930660", "layerId": "19732679917", "trafficAllocation": [], "forcedVariations": {}}], "id": "19732679917"}, {"experiments": [{"status": "Running", "audienceIds": [], "variations": [{"variables": [], "id": "19751331312", "key": "19751331312", "featureEnabled": true}], "id": "19732562643", "key": "19732562643", "layerId": "19736382992", "trafficAllocation": [], "forcedVariations": {}}], "id": "19736382992"}, {"experiments": [{"status": "Running", "audienceIds": [], "variations": [{"variables": [{"id": "19944494786", "value": "2"}], "id": "19960802027", "key": "19960802027", "featureEnabled": true}], "id": "19950761639", "key": "19950761639", "layerId": "19954212353", "trafficAllocation": [{"entityId": "19960802027", "endOfRange": 10000}], "forcedVariations": {}}], "id": "19954212353"}, {"experiments": [{"status": "Running", "audienceConditions": ["or", "19998648250"], "audienceIds": ["19998648250"], "variations": [{"variables": [{"id": "19957591217", "value": "false"}], "id": "20002546696", "key": "20002546696", "featureEnabled": true}], "id": "20021156353", "key": "20021156353", "layerId": "19956201394", "trafficAllocation": [], "forcedVariations": {}}, {"status": "Running", "audienceIds": [], "variations": [{"variables": [{"id": "19957591217", "value": "false"}], "id": "19965303945", "key": "19965303945", "featureEnabled": true}], "id": "19967235946", "key": "19967235946", "layerId": "19956201394", "trafficAllocation": [], "forcedVariations": {}}], "id": "19956201394"}, {"experiments": [{"status": "Running", "audienceIds": [], "variations": [{"variables": [], "id": "19973342048", "key": "19973342048", "featureEnabled": true}], "id": "19960353473", "key": "19960353473", "layerId": "19965472906", "trafficAllocation": [], "forcedVariations": {}}], "id": "19965472906"}, {"experiments": [{"status": "Running", "audienceIds": [], "variations": [{"variables": [{"id": "19988730003", "value": "{}"}], "id": "19994321492", "key": "19994321492", "featureEnabled": true}], "id": "19994331281", "key": "19994331281", "layerId": "20011181233", "trafficAllocation": [], "forcedVariations": {}}], "id": "20011181233"}, {"experiments": [{"status": "Running", "audienceConditions": ["or", "20087031244"], "audienceIds": ["20087031244"], "variations": [{"variables": [], "id": "20060209479", "key": "20060209479", "featureEnabled": true}], "id": "20079282484", "key": "20079282484", "layerId": "20066331797", "trafficAllocation": [{"entityId": "20060209479", "endOfRange": 10000}], "forcedVariations": {}}, {"status": "Running", "audienceConditions": ["or", "20085480105"], "audienceIds": ["20085480105"], "variations": [{"variables": [], "id": "20079372151", "key": "20079372151", "featureEnabled": true}], "id": "20056410452", "key": "20056410452", "layerId": "20066331797", "trafficAllocation": [], "forcedVariations": {}}, {"status": "Running", "audienceIds": [], "variations": [{"variables": [], "id": "20068300417", "key": "20068300417", "featureEnabled": true}], "id": "20073962076", "key": "20073962076", "layerId": "20066331797", "trafficAllocation": [], "forcedVariations": {}}], "id": "20066331797"}, {"experiments": [{"status": "Running", "audienceIds": [], "variations": [{"variables": [], "id": "20090353048", "key": "20090353048", "featureEnabled": true}], "id": "20088522972", "key": "20088522972", "layerId": "20088403635", "trafficAllocation": [{"entityId": "20090353048", "endOfRange": 10000}], "forcedVariations":  ...
#     'optimizelyOverrides': {'experiments': {}, 'features': {}},
#     'anonId': 'ba3b737c-838e-43ab-857b-81c675ff8096',
#     'userAgent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.37'}},
#   'initialState': {'filters': {'radius': {'options': [{'label': 'This area only',
#        'value': '0'},
#       {'label': '+ ¼ mile', 'value': '0.25'},
#       {'label': '+ ½ mile', 'value': '0.5'},
#       {'label': '+ 1 mile', 'value': '1'},
#       {'label': '+ 3 miles', 'value': '3'},
#       {'label': '+ 5 miles', 'value': '5'},
#       {'label': '+ 10 miles', 'value': '10'},
#       {'label': '+ 15 miles', 'value': '15'},
#       {'label': '+ 20 miles', 'value': '20'},
#       {'label': '+ 30 miles', 'value': '30'},
#       {'label': '+ 40 miles', 'value': '40'}],
#      'selectedValue': '0'},
#     'minBedrooms': {'options': [{'label': 'No min', 'value': ''},
#       {'label': 'Studio', 'value': '0'},
#       {'label': '1', 'value': '1'},
#       {'label': '2', 'value': '2'},
#       {'label': '3', 'value': '3'},
#       {'label': '4', 'value': '4'},
#       {'label': '5', 'value': '5'},
#       {'label': '6', 'value': '6'},
#       {'label': '7', 'value': '7'},
#       {'label': '8', 'value': '8'},
#       {'label': '9', 'value': '9'},
#       {'label': '10+', 'value': '10'}],
#      'selectedValue': ''},
#     'maxBedrooms': {'options': [{'label': 'No max', 'value': ''},
#       {'label': 'Studio', 'value': '0'},
#       {'label': '1', 'value': '1'},
#       {'label': '2', 'value': '2'},
#       {'label': '3', 'value': '3'},
#       {'label': '4', 'value': '4'},
#       {'label': '5', 'value': '5'},
#       {'label': '6', 'value': '6'},
#       {'label': '7', 'value': '7'},
#       {'label': '8', 'value': '8'},
#       {'label': '9', 'value': '9'},
#       {'label': '10+', 'value': '10'}],
#      'selectedValue': ''},
#     'propertyType': {'options': [{'label': 'Show all', 'value': ''},
#       {'label': 'Houses', 'value': 'houses'},
#       {'label': 'Flats', 'value': 'flats'},
#       {'label': 'Farms/land', 'value': 'farms_land'}],
#      'selectedValue': ''},
#     'minPrice': {'options': [{'label': 'No min', 'value': '0'},
#       {'label': '£10,000', 'value': '10000'},
#       {'label': '£20,000', 'value': '20000'},
#       {'label': '£30,000', 'value': '30000'},
#       {'label': '£40,000', 'value': '40000'},
#       {'label': '£50,000', 'value': '50000'},
#       {'label': '£60,000', 'value': '60000'},
#       {'label': '£70,000', 'value': '70000'},
#       {'label': '£80,000', 'value': '80000'},
#       {'label': '£90,000', 'value': '90000'},
#       {'label': '£100,000', 'value': '100000'},
#       {'label': '£110,000', 'value': '110000'},
#       {'label': '£120,000', 'value': '120000'},
#       {'label': '£125,000', 'value': '125000'},
#       {'label': '£130,000', 'value': '130000'},
#       {'label': '£140,000', 'value': '140000'},
#       {'label': '£150,000', 'value': '150000'},
#       {'label': '£160,000', 'value': '160000'},
#       {'label': '£170,000', 'value': '170000'},
#       {'label': '£180,000', 'value': '180000'},
#       {'label': '£190,000', 'value': '190000'},
#       {'label': '£200,000', 'value': '200000'},
#       {'label': '£210,000', 'value': '210000'},
#       {'label': '£220,000', 'value': '220000'},
#       {'label': '£230,000', 'value': '230000'},
#       {'label': '£240,000', 'value': '240000'},
#       {'label': '£250,000', 'value': '250000'},
#       {'label': '£275,000', 'value': '275000'},
#       {'label': '£300,000', 'value': '300000'},
#       {'label': '£325,000', 'value': '325000'},
#       {'label': '£350,000', 'value': '350000'},
#       {'label': '£375,000', 'value': '375000'},
#       {'label': '£400,000', 'value': '400000'},
#       {'label': '£425,000', 'value': '425000'},
#       {'label': '£450,000', 'value': '450000'},
#       {'label': '£475,000', 'value': '475000'},
#       {'label': '£500,000', 'value': '500000'},
#       {'label': '£550,000', 'value': '550000'},
#       {'label': '£600,000', 'value': '600000'},
#       {'label': '£650,000', 'value': '650000'},
#       {'label': '£700,000', 'value': '700000'},
#       {'label': '£750,000', 'value': '750000'},
#       {'label': '£800,000', 'value': '800000'},
#       {'label': '£850,000', 'value': '850000'},
#       {'label': '£900,000', 'value': '900000'},
#       {'label': '£950,000', 'value': '950000'},
#       {'label': '£1,000,000', 'value': '1000000'},
#       {'label': '£1,100,000', 'value': '1100000'},
#       {'label': '£1,200,000', 'value': '1200000'},
#       {'label': '£1,300,000', 'value': '1300000'},
#       {'label': '£1,400,000', 'value': '1400000'},
#       {'label': '£1,500,000', 'value': '1500000'},
#       {'label': '£1,600,000', 'value': '1600000'},
#       {'label': '£1,700,000', 'value': '1700000'},
#       {'label': '£1,800,000', 'value': '1800000'},
#       {'label': '£1,900,000', 'value': '1900000'},
#       {'label': '£2,000,000', 'value': '2000000'},
#       {'label': '£2,100,000', 'value': '2100000'},
#       {'label': '£2,200,000', 'value': '2200000'},
#       {'label': '£2,300,000', 'value': '2300000'},
#       {'label': '£2,400,000', 'value': '2400000'},
#       {'label': '£2,500,000', 'value': '2500000'},
#       {'label': '£2,750,000', 'value': '2750000'},
#       {'label': '£3,000,000', 'value': '3000000'},
#       {'label': '£3,250,000', 'value': '3250000'},
#       {'label': '£3,500,000', 'value': '3500000'},
#       {'label': '£3,750,000', 'value': '3750000'},
#       {'label': '£4,000,000', 'value': '4000000'},
#       {'label': '£4,250,000', 'value': '4250000'},
#       {'label': '£4,500,000', 'value': '4500000'},
#       {'label': '£4,750,000', 'value': '4750000'},
#       {'label': '£5,000,000', 'value': '5000000'},
#       {'label': '£5,500,000', 'value': '5500000'},
#       {'label': '£6,000,000', 'value': '6000000'},
#       {'label': '£6,500,000', 'value': '6500000'},
#       {'label': '£7,000,000', 'value': '7000000'},
#       {'label': '£7,500,000', 'value': '7500000'},
#       {'label': '£8,000,000', 'value': '8000000'},
#       {'label': '£8,500,000', 'value': '8500000'},
#       {'label': '£9,000,000', 'value': '9000000'},
#       {'label': '£9,500,000', 'value': '9500000'},
#       {'label': '£10,000,000', 'value': '10000000'},
#       {'label': '£12,500,000', 'value': '12500000'},
#       {'label': '£15,000,000', 'value': '15000000'}],
#      'selectedValue': '0'},
#     'maxPrice': {'options': [{'label': 'No max', 'value': '0'},
#       {'label': '£10,000', 'value': '10000'},
#       {'label': '£20,000', 'value': '20000'},
#       {'label': '£30,000', 'value': '30000'},
#       {'label': '£40,000', 'value': '40000'},
#       {'label': '£50,000', 'value': '50000'},
#       {'label': '£60,000', 'value': '60000'},
#       {'label': '£70,000', 'value': '70000'},
#       {'label': '£80,000', 'value': '80000'},
#       {'label': '£90,000', 'value': '90000'},
#       {'label': '£100,000', 'value': '100000'},
#       {'label': '£110,000', 'value': '110000'},
#       {'label': '£120,000', 'value': '120000'},
#       {'label': '£125,000', 'value': '125000'},
#       {'label': '£130,000', 'value': '130000'},
#       {'label': '£140,000', 'value': '140000'},
#       {'label': '£150,000', 'value': '150000'},
#       {'label': '£160,000', 'value': '160000'},
#       {'label': '£170,000', 'value': '170000'},
#       {'label': '£180,000', 'value': '180000'},
#       {'label': '£190,000', 'value': '190000'},
#       {'label': '£200,000', 'value': '200000'},
#       {'label': '£210,000', 'value': '210000'},
#       {'label': '£220,000', 'value': '220000'},
#       {'label': '£230,000', 'value': '230000'},
#       {'label': '£240,000', 'value': '240000'},
#       {'label': '£250,000', 'value': '250000'},
#       {'label': '£275,000', 'value': '275000'},
#       {'label': '£300,000', 'value': '300000'},
#       {'label': '£325,000', 'value': '325000'},
#       {'label': '£350,000', 'value': '350000'},
#       {'label': '£375,000', 'value': '375000'},
#       {'label': '£400,000', 'value': '400000'},
#       {'label': '£425,000', 'value': '425000'},
#       {'label': '£450,000', 'value': '450000'},
#       {'label': '£475,000', 'value': '475000'},
#       {'label': '£500,000', 'value': '500000'},
#       {'label': '£550,000', 'value': '550000'},
#       {'label': '£600,000', 'value': '600000'},
#       {'label': '£650,000', 'value': '650000'},
#       {'label': '£700,000', 'value': '700000'},
#       {'label': '£750,000', 'value': '750000'},
#       {'label': '£800,000', 'value': '800000'},
#       {'label': '£850,000', 'value': '850000'},
#       {'label': '£900,000', 'value': '900000'},
#       {'label': '£950,000', 'value': '950000'},
#       {'label': '£1,000,000', 'value': '1000000'},
#       {'label': '£1,100,000', 'value': '1100000'},
#       {'label': '£1,200,000', 'value': '1200000'},
#       {'label': '£1,300,000', 'value': '1300000'},
#       {'label': '£1,400,000', 'value': '1400000'},
#       {'label': '£1,500,000', 'value': '1500000'},
#       {'label': '£1,600,000', 'value': '1600000'},
#       {'label': '£1,700,000', 'value': '1700000'},
#       {'label': '£1,800,000', 'value': '1800000'},
#       {'label': '£1,900,000', 'value': '1900000'},
#       {'label': '£2,000,000', 'value': '2000000'},
#       {'label': '£2,100,000', 'value': '2100000'},
#       {'label': '£2,200,000', 'value': '2200000'},
#       {'label': '£2,300,000', 'value': '2300000'},
#       {'label': '£2,400,000', 'value': '2400000'},
#       {'label': '£2,500,000', 'value': '2500000'},
#       {'label': '£2,750,000', 'value': '2750000'},
#       {'label': '£3,000,000', 'value': '3000000'},
#       {'label': '£3,250,000', 'value': '3250000'},
#       {'label': '£3,500,000', 'value': '3500000'},
#       {'label': '£3,750,000', 'value': '3750000'},
#       {'label': '£4,000,000', 'value': '4000000'},
#       {'label': '£4,250,000', 'value': '4250000'},
#       {'label': '£4,500,000', 'value': '4500000'},
#       {'label': '£4,750,000', 'value': '4750000'},
#       {'label': '£5,000,000', 'value': '5000000'},
#       {'label': '£5,500,000', 'value': '5500000'},
#       {'label': '£6,000,000', 'value': '6000000'},
#       {'label': '£6,500,000', 'value': '6500000'},
#       {'label': '£7,000,000', 'value': '7000000'},
#       {'label': '£7,500,000', 'value': '7500000'},
#       {'label': '£8,000,000', 'value': '8000000'},
#       {'label': '£8,500,000', 'value': '8500000'},
#       {'label': '£9,000,000', 'value': '9000000'},
#       {'label': '£9,500,000', 'value': '9500000'},
#       {'label': '£10,000,000', 'value': '10000000'},
#       {'label': '£12,500,000', 'value': '12500000'},
#       {'label': '£15,000,000', 'value': '15000000'}],
#      'selectedValue': '0'},
#     'minPriceWeekly': {'options': [{'label': 'No min', 'value': '0'},
#       {'label': '£25 pw', 'value': '25'},
#       {'label': '£50 pw', 'value': '50'},
#       {'label': '£75 pw', 'value': '75'},
#       {'label': '£100 pw', 'value': '100'},
#       {'label': '£125 pw', 'value': '125'},
#       {'label': '£150 pw', 'value': '150'},
#       {'label': '£175 pw', 'value': '175'},
#       {'label': '£200 pw', 'value': '200'},
#       {'label': '£225 pw', 'value': '225'},
#       {'label': '£250 pw', 'value': '250'},
#       {'label': '£275 pw', 'value': '275'},
#       {'label': '£300 pw', 'value': '300'},
#       {'label': '£325 pw', 'value': '325'},
#       {'label': '£350 pw', 'value': '350'},
#       {'label': '£375 pw', 'value': '375'},
#       {'label': '£400 pw', 'value': '400'},
#       {'label': '£425 pw', 'value': '425'},
#       {'label': '£450 pw', 'value': '450'},
#       {'label': '£475 pw', 'value': '475'},
#       {'label': '£500 pw', 'value': '500'},
#       {'label': '£550 pw', 'value': '550'},
#       {'label': '£600 pw', 'value': '600'},
#       {'label': '£650 pw', 'value': '650'},
#       {'label': '£700 pw', 'value': '700'},
#       {'label': '£750 pw', 'value': '750'},
#       {'label': '£800 pw', 'value': '800'},
#       {'label': '£850 pw', 'value': '850'},
#       {'label': '£900 pw', 'value': '900'},
#       {'label': '£950 pw', 'value': '950'},
#       {'label': '£1,000 pw', 'value': '1000'},
#       {'label': '£1,250 pw', 'value': '1250'},
#       {'label': '£1,500 pw', 'value': '1500'},
#       {'label': '£1,750 pw', 'value': '1750'},
#       {'label': '£2,000 pw', 'value': '2000'},
#       {'label': '£2,500 pw', 'value': '2500'},
#       {'label': '£3,000 pw', 'value': '3000'},
#       {'label': '£3,500 pw', 'value': '3500'},
#       {'label': '£4,000 pw', 'value': '4000'},
#       {'label': '£4,500 pw', 'value': '4500'},
#       {'label': '£5,000 pw', 'value': '5000'},
#       {'label': '£7,500 pw', 'value': '7500'}],
#      'selectedValue': '0'},
#     'maxPriceWeekly': {'options': [{'label': 'No max', 'value': '0'},
#       {'label': '£25 pw', 'value': '25'},
#       {'label': '£50 pw', 'value': '50'},
#       {'label': '£75 pw', 'value': '75'},
#       {'label': '£100 pw', 'value': '100'},
#       {'label': '£125 pw', 'value': '125'},
#       {'label': '£150 pw', 'value': '150'},
#       {'label': '£175 pw', 'value': '175'},
#       {'label': '£200 pw', 'value': '200'},
#       {'label': '£225 pw', 'value': '225'},
#       {'label': '£250 pw', 'value': '250'},
#       {'label': '£275 pw', 'value': '275'},
#       {'label': '£300 pw', 'value': '300'},
#       {'label': '£325 pw', 'value': '325'},
#       {'label': '£350 pw', 'value': '350'},
#       {'label': '£375 pw', 'value': '375'},
#       {'label': '£400 pw', 'value': '400'},
#       {'label': '£425 pw', 'value': '425'},
#       {'label': '£450 pw', 'value': '450'},
#       {'label': '£475 pw', 'value': '475'},
#       {'label': '£500 pw', 'value': '500'},
#       {'label': '£550 pw', 'value': '550'},
#       {'label': '£600 pw', 'value': '600'},
#       {'label': '£650 pw', 'value': '650'},
#       {'label': '£700 pw', 'value': '700'},
#       {'label': '£750 pw', 'value': '750'},
#       {'label': '£800 pw', 'value': '800'},
#       {'label': '£850 pw', 'value': '850'},
#       {'label': '£900 pw', 'value': '900'},
#       {'label': '£950 pw', 'value': '950'},
#       {'label': '£1,000 pw', 'value': '1000'},
#       {'label': '£1,250 pw', 'value': '1250'},
#       {'label': '£1,500 pw', 'value': '1500'},
#       {'label': '£1,750 pw', 'value': '1750'},
#       {'label': '£2,000 pw', 'value': '2000'},
#       {'label': '£2,500 pw', 'value': '2500'},
#       {'label': '£3,000 pw', 'value': '3000'},
#       {'label': '£3,500 pw', 'value': '3500'},
#       {'label': '£4,000 pw', 'value': '4000'},
#       {'label': '£4,500 pw', 'value': '4500'},
#       {'label': '£5,000 pw', 'value': '5000'},
#       {'label': '£7,500 pw', 'value': '7500'}],
#      'selectedValue': '0'},
#     'minPriceMonthly': {'options': [{'label': 'No min', 'value': '0'},
#       {'label': '£100 pcm', 'value': '100'},
#       {'label': '£200 pcm', 'value': '200'},
#       {'label': '£300 pcm', 'value': '300'},
#       {'label': '£400 pcm', 'value': '400'},
#       {'label': '£500 pcm', 'value': '500'},
#       {'label': '£600 pcm', 'value': '600'},
#       {'label': '£700 pcm', 'value': '700'},
#       {'label': '£800 pcm', 'value': '800'},
#       {'label': '£900 pcm', 'value': '900'},
#       {'label': '£1,000 pcm', 'value': '1000'},
#       {'label': '£1,250 pcm', 'value': '1250'},
#       {'label': '£1,500 pcm', 'value': '1500'},
#       {'label': '£1,750 pcm', 'value': '1750'},
#       {'label': '£2,000 pcm', 'value': '2000'},
#       {'label': '£2,250 pcm', 'value': '2250'},
#       {'label': '£2,500 pcm', 'value': '2500'},
#       {'label': '£2,750 pcm', 'value': '2750'},
#       {'label': '£3,000 pcm', 'value': '3000'},
#       {'label': '£3,250 pcm', 'value': '3250'},
#       {'label': '£3,500 pcm', 'value': '3500'},
#       {'label': '£3,750 pcm', 'value': '3750'},
#       {'label': '£4,000 pcm', 'value': '4000'},
#       {'label': '£4,250 pcm', 'value': '4250'},
#       {'label': '£4,500 pcm', 'value': '4500'},
#       {'label': '£4,750 pcm', 'value': '4750'},
#       {'label': '£5,000 pcm', 'value': '5000'},
#       {'label': '£5,500 pcm', 'value': '5500'},
#       {'label': '£6,000 pcm', 'value': '6000'},
#       {'label': '£6,500 pcm', 'value': '6500'},
#       {'label': '£7,000 pcm', 'value': '7000'},
#       {'label': '£7,500 pcm', 'value': '7500'},
#       {'label': '£8,000 pcm', 'value': '8000'},
#       {'label': '£8,500 pcm', 'value': '8500'},
#       {'label': '£9,000 pcm', 'value': '9000'},
#       {'label': '£9,500 pcm', 'value': '9500'},
#       {'label': '£10,000 pcm', 'value': '10000'},
#       {'label': '£12,500 pcm', 'value': '12500'},
#       {'label': '£15,000 pcm', 'value': '15000'},
#       {'label': '£17,500 pcm', 'value': '17500'},
#       {'label': '£20,000 pcm', 'value': '20000'},
#       {'label': '£25,000 pcm', 'value': '25000'}],
#      'selectedValue': '0'},
#     'maxPriceMonthly': {'options': [{'label': 'No max', 'value': '0'},
#       {'label': '£100 pcm', 'value': '100'},
#       {'label': '£200 pcm', 'value': '200'},
#       {'label': '£300 pcm', 'value': '300'},
#       {'label': '£400 pcm', 'value': '400'},
#       {'label': '£500 pcm', 'value': '500'},
#       {'label': '£600 pcm', 'value': '600'},
#       {'label': '£700 pcm', 'value': '700'},
#       {'label': '£800 pcm', 'value': '800'},
#       {'label': '£900 pcm', 'value': '900'},
#       {'label': '£1,000 pcm', 'value': '1000'},
#       {'label': '£1,250 pcm', 'value': '1250'},
#       {'label': '£1,500 pcm', 'value': '1500'},
#       {'label': '£1,750 pcm', 'value': '1750'},
#       {'label': '£2,000 pcm', 'value': '2000'},
#       {'label': '£2,250 pcm', 'value': '2250'},
#       {'label': '£2,500 pcm', 'value': '2500'},
#       {'label': '£2,750 pcm', 'value': '2750'},
#       {'label': '£3,000 pcm', 'value': '3000'},
#       {'label': '£3,250 pcm', 'value': '3250'},
#       {'label': '£3,500 pcm', 'value': '3500'},
#       {'label': '£3,750 pcm', 'value': '3750'},
#       {'label': '£4,000 pcm', 'value': '4000'},
#       {'label': '£4,250 pcm', 'value': '4250'},
#       {'label': '£4,500 pcm', 'value': '4500'},
#       {'label': '£4,750 pcm', 'value': '4750'},
#       {'label': '£5,000 pcm', 'value': '5000'},
#       {'label': '£5,500 pcm', 'value': '5500'},
#       {'label': '£6,000 pcm', 'value': '6000'},
#       {'label': '£6,500 pcm', 'value': '6500'},
#       {'label': '£7,000 pcm', 'value': '7000'},
#       {'label': '£7,500 pcm', 'value': '7500'},
#       {'label': '£8,000 pcm', 'value': '8000'},
#       {'label': '£8,500 pcm', 'value': '8500'},
#       {'label': '£9,000 pcm', 'value': '9000'},
#       {'label': '£9,500 pcm', 'value': '9500'},
#       {'label': '£10,000 pcm', 'value': '10000'},
#       {'label': '£12,500 pcm', 'value': '12500'},
#       {'label': '£15,000 pcm', 'value': '15000'},
#       {'label': '£17,500 pcm', 'value': '17500'},
#       {'label': '£20,000 pcm', 'value': '20000'},
#       {'label': '£25,000 pcm', 'value': '25000'}],
#      'selectedValue': '0'},
#     'priceFrequency': {'options': [{'label': 'Month', 'value': 'per_month'},
#       {'label': 'Week', 'value': 'per_week'}],
#      'selectedValue': ''},
#     'propertySubTypes': {'options': [{'label': 'Detached house',
#        'value': 'detached'},
#       {'label': 'Semi-detached house', 'value': 'semi_detached'},
#       {'label': 'Terraced house', 'value': 'terraced'},
#       {'label': 'Bungalow', 'value': 'bungalow'},
#       {'label': 'Detached bungalow', 'value': 'detached_bungalow'},
#       {'label': 'Semi-detached bungalow', 'value': 'semi_detached_bungalow'},
#       {'label': 'Terraced bungalow', 'value': 'terraced_bungalow'},
#       {'label': 'Cottage', 'value': 'cottage'},
#       {'label': 'Mobile/park home', 'value': 'park_home'}],
#      'selectedValue': []},
#     'propertyAdded': {'options': [{'label': 'Added anytime', 'value': ''},
#       {'label': 'Last 24 hours', 'value': '24_hours'},
#       {'label': 'Last 3 days', 'value': '3_days'},
#       {'label': 'Last 7 days', 'value': '7_days'},
#       {'label': 'Last 14 days', 'value': '14_days'},
#       {'label': 'Last 30 days', 'value': '30_days'}],
#      'selectedValue': ''},
#     'availableFrom': {'options': [{'label': 'Available anytime', 'value': ''},
#       {'label': 'Immediately', 'value': 'now'},
#       {'label': 'Within 1 month', 'value': '1months'},
#       {'label': 'Within 3 months', 'value': '3months'},
#       {'label': 'Within 6 months', 'value': '6months'},
#       {'label': 'Within 1 year', 'value': '12months'}],
#      'selectedValue': ''},
#     'billsIncluded': {'label': 'Bills included', 'selectedValue': False},
#     'underOfferOrSold': {'label': 'Under offer / Sold STC',
#      'selectedValue': False},
#     'chainFree': {'label': 'Chain-free', 'selectedValue': False},
#     'priceReduced': {'label': 'Price-reduced', 'selectedValue': False},
#     'includeSharedAccommodation': {'label': 'Include shared accommodation',
#      'selectedValue': True},
#     'includeRented': {'label': 'Include let or let agreed',
#      'selectedValue': False},
#     'furnishedState': {'options': [{'label': 'Any', 'value': 'Any'},
#       {'label': 'Furnished', 'value': 'furnished'},
#       {'label': 'Part-furnished', 'value': 'part_furnished'},
#       {'label': 'Unfurnished', 'value': 'unfurnished'}],
#      'selectedValue': 'Any'},
#     'petsAllowed': {'label': 'Pets allowed', 'selectedValue': False},
#     'rentalTerm': {'label': 'Short lets', 'selectedValue': False},
#     'mustHaves': {'options': [{'label': 'Garden', 'value': 'has_garden'},
#       {'label': 'Parking / garage', 'value': 'has_parking_garage'},
#       {'label': 'Balcony / terrace', 'value': 'has_balcony_terrace'},
#       {'label': 'Porter / security', 'value': 'has_porter_security'},
#       {'label': 'Wood floors', 'value': 'has_wood_floors'},
#       {'label': 'Fireplace', 'value': 'has_fireplace'},
#       {'label': 'Rural / secluded', 'value': 'is_rural_secluded'}],
#      'selectedValue': []},
#     'isSharedOwnership': {'label': 'Shared ownership',
#      'selectedValue': True,
#      'disabled': False},
#     'auction': {'label': 'Auction', 'selectedValue': True, 'disabled': False},
#     'retirementHome': {'label': 'Retirement', 'selectedValue': False},
#     'newHomes': {'label': 'New homes', 'selectedValue': False},
#     'preOwned': {'label': 'Pre-owned', 'selectedValue': False},
#     'incentives': {'label': 'Help to buy', 'selectedValue': False},
#     'keywords': {'label': 'Keywords',
#      'tip': 'Search for phrases by using quotations marks e.g. “double garage”, or exclude terms by prefixing them with a minus sign e.g. -studio.',
#      'placeholder': 'e.g. conservatory or “double garage”',
#      'selectedValue': ''},
#     'duration': {'options': [{'label': '15 minutes', 'value': '900'},
#       {'label': '30 minutes', 'value': '1800'},
#       {'label': '45 minutes', 'value': '2700'},
#       {'label': '1 hour', 'value': '3600'},
#       {'label': '1 ¼ hour', 'value': '4500'}],
#      'selectedValue': ''},
#     'transportType': {'options': [{'label': 'Driving', 'value': 'driving'},
#       {'label': 'Walking', 'value': 'walking'},
#       {'label': 'Train', 'value': 'walking_train'},
#       {'label': 'Public transport', 'value': 'public_transport'},
#       {'label': 'Cycling', 'value': 'cycling'}],
#      'selectedValue': ''},
#     'q': {'selectedValue': ''},
#     'identifier': {'selectedValue': ''},
#     'locationText': {'selectedValue': ''}},
#    'listingsSortOrder': {'currentSortOrder': 'newest_listings', 'options': []},
#    'searchResults': {'totalResults': 0,
#     'pageNumber': 0,
#     'totalResultsWasLimited': False,
#     'polyenc': None},
#    'taxonomy': {'taxonomy': {}},
#    'optimizely': {'forcedFeatures': {}},
#    'user': {'loading': False,
#     'loggedIn': False,
#     'senderPropertyStatus': None,
#     'creationDate': None,
#     'userId': None,
#     'userUuid': None,
#     'error': []}}},
#  'page': '/for-sale/details/[listingId]',
#  'query': {'listingId': '58426277'},
#  'buildId': 'j9Iu7ekjoofduXRM3CvSl',
#  'assetPrefix': 'https://r.zoocdn.com',
#  'runtimeConfig': {'GTM_ID': 'GTM-WNFR4ZC',
#   'SEGMENT_ID': 'kMettuB218zyYLIzUsT2ptxdGiEtWYT2',
#   'GRAPHQL_API': 'https://api-graphql-lambda.prod.zoopla.co.uk/graphql',
#   'API_KEY': '3Vzj2wUfaP3euLsV4NV9h3UAVUR3BoWd5clv9Dvu',
#   'SIGNIN_PATH': '/signin/',
#   'REGISTER_PATH': '/register/',
#   'MAPS_CLIENT_ID': 'gme-zooplapropertygroup',
#   'NEW_RELIC': {'ACCOUNT_ID': '2902499',
#    'APP_ID': '95776729',
#    'LICENCE_KEY': 'NRJS-87cb4c448aca56623be',
#    'BEACON': 'bam.eu01.nr-data.net',
#    'DISABLE': False}},
#  'isFallback': False,
#  'customServer': True,
#  'gip': True,
#  'appGip': True}

# %%
rows
# Out:
# [{'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 15,
#   'acornType': 15,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 80795,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(592983).png',
#   'branchName': 'Foxtons - Vauxhall',
#   'brandName': 'Foxtons',
#   'chainFree': False,
#   'companyId': 1370,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Latvia Court, Walworth, London SE17',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '3HB',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58426277,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 11,
#   'numRecepts': 1,
#   'outcode': 'SE17',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 475000,
#   'price': 475000,
#   'priceMax': 475000,
#   'priceMin': 475000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': None,
#   'zindex': 465263},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 15,
#   'acornType': 15,
#   'areaName': 'London',
#   'bedsMax': 1,
#   'bedsMin': 1,
#   'branchId': 9539,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(26551).gif',
#   'branchName': 'riverhomes, South West & Central London office',
#   'brandName': 'riverhomes',
#   'chainFree': False,
#   'companyId': 6403,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Nine Elms Pier, Tideway Walk, Nine Elms SW8',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '5PZ',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58425589,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 1,
#   'numImages': 9,
#   'numRecepts': 1,
#   'outcode': 'SW8',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 270000,
#   'price': 270000,
#   'priceMax': 275000,
#   'priceMin': 250000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'houseboat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': None,
#   'zindex': None},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 16,
#   'acornType': 16,
#   'areaName': 'London',
#   'bedsMax': 3,
#   'bedsMin': 3,
#   'branchId': 101641,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(249290).png',
#   'branchName': 'Winkworth - Kennington Sales',
#   'brandName': 'Winkworth',
#   'chainFree': False,
#   'companyId': 4040,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Ravensdon Street, Kennington, London SE11',
#   'furnishedState': '',
#   'groupId': 44,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '4AR',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58425076,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 3,
#   'numImages': 16,
#   'numRecepts': 2,
#   'outcode': 'SE11',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 1350000,
#   'price': 1350000,
#   'priceMax': 1400000,
#   'priceMin': 1300000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 719209},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 8169,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(249290).png',
#   'branchName': 'Winkworth - Dulwich',
#   'brandName': 'Winkworth',
#   'chainFree': False,
#   'companyId': 4040,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Hillsboro Road, East Dulwich, London SE22',
#   'furnishedState': '',
#   'groupId': 44,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '8QE',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58424849,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 12,
#   'numRecepts': 1,
#   'outcode': 'SE22',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 700000,
#   'price': 700000,
#   'priceMax': 700000,
#   'priceMin': 700000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'leasehold',
#   'zindex': 735798},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 17,
#   'acornType': 17,
#   'areaName': 'London',
#   'bedsMax': 1,
#   'bedsMin': 1,
#   'branchId': 58933,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(584439).png',
#   'branchName': 'Purplebricks, Head Office',
#   'brandName': 'Purplebricks',
#   'chainFree': False,
#   'companyId': 31628,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Herne Hill Road, Herne Hill SE24',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '0AR',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 45213795,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 1,
#   'numImages': 11,
#   'numRecepts': 1,
#   'outcode': 'SE24',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 440000,
#   'price': 440000,
#   'priceMax': 450000,
#   'priceMin': 425000,
#   'priceQualifier': 'guide_price',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 418797},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 15,
#   'acornType': 15,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 93947,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(687104).png',
#   'branchName': 'Moveli',
#   'brandName': 'Moveli',
#   'chainFree': True,
#   'companyId': 69787,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Willow Lodge, 195 Cedars Road, London SW4',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '0PU',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58424238,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 2,
#   'numImages': 14,
#   'numRecepts': 1,
#   'outcode': 'SW4',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 550000,
#   'price': 550000,
#   'priceMax': 550000,
#   'priceMin': 550000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '796',
#   'tenure': None,
#   'zindex': 670865},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 15,
#   'acornType': 15,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 104328,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(295280).png',
#   'branchName': 'Marsh & Parsons - Streatham Hill',
#   'brandName': 'Marsh & Parsons',
#   'chainFree': False,
#   'companyId': 7059,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'The High, Streatham High Road SW16',
#   'furnishedState': '',
#   'groupId': 10,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '1EY',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 56454597,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 9,
#   'numRecepts': 2,
#   'outcode': 'SW16',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 440000,
#   'price': 440000,
#   'priceMax': 450000,
#   'priceMin': 425000,
#   'priceQualifier': 'guide_price',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'leasehold',
#   'zindex': 392583},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 55,
#   'acornType': 55,
#   'areaName': 'London',
#   'bedsMax': 3,
#   'bedsMin': 3,
#   'branchId': 58933,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(584439).png',
#   'branchName': 'Purplebricks, Head Office',
#   'brandName': 'Purplebricks',
#   'chainFree': False,
#   'companyId': 31628,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Abbots Park, London SW2',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '3QZ',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58423971,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 3,
#   'numImages': 12,
#   'numRecepts': 2,
#   'outcode': 'SW2',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 350000,
#   'price': 350000,
#   'priceMax': 350000,
#   'priceMin': 350000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'leasehold',
#   'zindex': 368083},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 17,
#   'acornType': 17,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 61799,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(466896).png',
#   'branchName': 'Pedder - West Norwood',
#   'brandName': 'Pedder',
#   'chainFree': False,
#   'companyId': 29514,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Ullswater Road, West Norwood, London SE27',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '0AL',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58423947,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 2,
#   'numImages': 10,
#   'numRecepts': 1,
#   'outcode': 'SE27',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 650000,
#   'price': 650000,
#   'priceMax': 650000,
#   'priceMin': 650000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': None,
#   'zindex': 393301},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 4,
#   'bedsMin': 4,
#   'branchId': 14233,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(275279).png',
#   'branchName': 'Jacksons Estate Agents - Streatham',
#   'brandName': 'Jacksons Estate Agents',
#   'chainFree': False,
#   'companyId': 7064,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Amesbury Avenue, London SW2',
#   'furnishedState': '',
#   'groupId': 24,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '3AE',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58423662,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 4,
#   'numImages': 11,
#   'numRecepts': 1,
#   'outcode': 'SW2',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 975000,
#   'price': 975000,
#   'priceMax': 1000000,
#   'priceMin': 950000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': '',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 462693},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 14,
#   'acornType': 14,
#   'areaName': 'London',
#   'bedsMax': 3,
#   'bedsMin': 3,
#   'branchId': 58933,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(584439).png',
#   'branchName': 'Purplebricks, Head Office',
#   'brandName': 'Purplebricks',
#   'chainFree': False,
#   'companyId': 31628,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Iveley Road, Clapham SW4',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '0EW',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58423304,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 3,
#   'numImages': 11,
#   'numRecepts': 1,
#   'outcode': 'SW4',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 900000,
#   'price': 900000,
#   'priceMax': 900000,
#   'priceMin': 900000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 835527},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 6,
#   'bedsMin': 6,
#   'branchId': 115668,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(644074).png',
#   'branchName': 'Knight Frank - Dulwich Village Sales',
#   'brandName': 'Knight Frank',
#   'chainFree': False,
#   'companyId': 2182,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Lovelace Road, West Dulwich, London SE21',
#   'furnishedState': 'unfurnished',
#   'groupId': 94,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '8JR',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58421831,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 6,
#   'numImages': 21,
#   'numRecepts': 4,
#   'outcode': 'SE21',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 2250000,
#   'price': 2250000,
#   'priceMax': 2300000,
#   'priceMin': 2200000,
#   'priceQualifier': 'guide_price',
#   'propertyHighlight': '',
#   'propertyType': 'detached',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '4221',
#   'tenure': None,
#   'zindex': 1396455},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 16,
#   'acornType': 16,
#   'areaName': 'London',
#   'bedsMax': 4,
#   'bedsMin': 4,
#   'branchId': 6240,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(643976).png',
#   'branchName': 'Rampton Baseley',
#   'brandName': 'Rampton Baseley',
#   'chainFree': False,
#   'companyId': 3133,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Iveley Road, London SW4',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '0EN',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58421463,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 4,
#   'numImages': 13,
#   'numRecepts': 2,
#   'outcode': 'SW4',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 1400000,
#   'price': 1400000,
#   'priceMax': 1400000,
#   'priceMin': 1400000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': None},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': None,
#   'acornType': None,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 115075,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(706508).png',
#   'branchName': 'MyLondonHome Battersea',
#   'brandName': 'MyLondonHome',
#   'chainFree': False,
#   'companyId': 8191,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Three Riverlight Quay, Nine Elms SW11',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '8BE',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58421391,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 2,
#   'numImages': 16,
#   'numRecepts': 1,
#   'outcode': 'SW11',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 1300000,
#   'price': 1300000,
#   'priceMax': 1300000,
#   'priceMin': 1300000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '988',
#   'tenure': 'leasehold',
#   'zindex': None},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 14,
#   'acornType': 14,
#   'areaName': 'London',
#   'bedsMax': 3,
#   'bedsMin': 3,
#   'branchId': 104185,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(623201).png',
#   'branchName': 'Keller Williams London Bridge',
#   'brandName': 'Keller Williams',
#   'chainFree': False,
#   'companyId': 33518,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': '3 All Saints Close, Stockwell, London SW8',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '2PW',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58421382,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 3,
#   'numBeds': 3,
#   'numImages': 21,
#   'numRecepts': 2,
#   'outcode': 'SW8',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 1500000,
#   'price': 1500000,
#   'priceMax': 1500000,
#   'priceMin': 1500000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 1197398},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 17034,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(479408).png',
#   'branchName': 'Wooster & Stock',
#   'brandName': 'Wooster & Stock',
#   'chainFree': False,
#   'companyId': 8488,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Benhill Road, Camberwell SE5',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '7LZ',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58421284,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 28,
#   'numRecepts': 1,
#   'outcode': 'SE5',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 825000,
#   'price': 825000,
#   'priceMax': 850000,
#   'priceMin': 800000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'end_terrace',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '1002',
#   'tenure': None,
#   'zindex': 484043},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 54,
#   'acornType': 54,
#   'areaName': 'London',
#   'bedsMax': 1,
#   'bedsMin': 1,
#   'branchId': 1349,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(293928).png',
#   'branchName': 'Portico - Clapham',
#   'brandName': 'Portico',
#   'chainFree': True,
#   'companyId': 581,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Brandon Estate, London SE17',
#   'furnishedState': '',
#   'groupId': 69,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '3NN',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420999,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': None,
#   'numBeds': 1,
#   'numImages': 7,
#   'numRecepts': None,
#   'outcode': 'SE17',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 270000,
#   'price': 270000,
#   'priceMax': 275000,
#   'priceMin': 250000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'leasehold',
#   'zindex': 334239},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 73366,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(313962).png',
#   'branchName': 'Urban Village',
#   'brandName': 'Urban Village',
#   'chainFree': False,
#   'companyId': 40881,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Springhill Close, London SE5',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '8AJ',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420792,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 14,
#   'numRecepts': None,
#   'outcode': 'SE5',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 465000,
#   'price': 465000,
#   'priceMax': 475000,
#   'priceMin': 450000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': None,
#   'zindex': 459446},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 16,
#   'acornType': 16,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 16402,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(326710).png',
#   'branchName': 'James Pendleton, Clapham Common & Brixton Office',
#   'brandName': 'James Pendleton',
#   'chainFree': False,
#   'companyId': 1965,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'The Chase, Clapham, London SW4',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '0NP',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420138,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 11,
#   'numRecepts': 1,
#   'outcode': 'SW4',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 495000,
#   'price': 495000,
#   'priceMax': 500000,
#   'priceMin': 475000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'share_of_freehold',
#   'zindex': 663345},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 17,
#   'acornType': 17,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 32650,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(592983).png',
#   'branchName': 'Foxtons - Streatham',
#   'brandName': 'Foxtons',
#   'chainFree': False,
#   'companyId': 1370,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Knollys Road, Streatham, London SW16',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '2JU',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420124,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 8,
#   'numRecepts': 1,
#   'outcode': 'SW16',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 350000,
#   'price': 350000,
#   'priceMax': 350000,
#   'priceMin': 350000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': None,
#   'zindex': 553429},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 14,
#   'acornType': 14,
#   'areaName': 'London',
#   'bedsMax': 4,
#   'bedsMin': 4,
#   'branchId': 56771,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(358974).png',
#   'branchName': 'Dexters - Clapham',
#   'brandName': 'Dexters',
#   'chainFree': False,
#   'companyId': 1096,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Caldervale Road, London SW4',
#   'furnishedState': '',
#   'groupId': 24,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '9LY',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420064,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 4,
#   'numImages': 7,
#   'numRecepts': 2,
#   'outcode': 'SW4',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 1499950,
#   'price': 1499950,
#   'priceMax': 1500000,
#   'priceMin': 1400000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': '',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '18837',
#   'tenure': 'freehold',
#   'zindex': 757103},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 46,
#   'acornType': 46,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 3591,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(707660).png',
#   'branchName': 'Hamptons - Clapham Sales',
#   'brandName': 'Hamptons',
#   'chainFree': False,
#   'companyId': 1612,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Heather Close, London SW8',
#   'furnishedState': '',
#   'groupId': 8,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '3BS',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420020,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 2,
#   'numImages': 9,
#   'numRecepts': 1,
#   'outcode': 'SW8',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 615000,
#   'price': 615000,
#   'priceMax': 650000,
#   'priceMin': 600000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'leasehold',
#   'zindex': 476391},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 3,
#   'bedsMin': 3,
#   'branchId': 80066,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(701121).png',
#   'branchName': 'Acorn - Camberwell',
#   'brandName': 'Acorn',
#   'chainFree': True,
#   'companyId': 8143,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Canning Cross, London SE5',
#   'furnishedState': '',
#   'groupId': 25,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '8BH',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58419984,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 3,
#   'numImages': 15,
#   'numRecepts': 1,
#   'outcode': 'SE5',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 690000,
#   'price': 690000,
#   'priceMax': 700000,
#   'priceMin': 650000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 724818},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 15,
#   'acornType': 15,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 80795,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(592983).png',
#   'branchName': 'Foxtons - Vauxhall',
#   'brandName': 'Foxtons',
#   'chainFree': False,
#   'companyId': 1370,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Latvia Court, Walworth, London SE17',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '3HB',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58426277,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 11,
#   'numRecepts': 1,
#   'outcode': 'SE17',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 475000,
#   'price': 475000,
#   'priceMax': 475000,
#   'priceMin': 475000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': None,
#   'zindex': 465263},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 15,
#   'acornType': 15,
#   'areaName': 'London',
#   'bedsMax': 1,
#   'bedsMin': 1,
#   'branchId': 9539,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(26551).gif',
#   'branchName': 'riverhomes, South West & Central London office',
#   'brandName': 'riverhomes',
#   'chainFree': False,
#   'companyId': 6403,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Nine Elms Pier, Tideway Walk, Nine Elms SW8',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '5PZ',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58425589,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 1,
#   'numImages': 9,
#   'numRecepts': 1,
#   'outcode': 'SW8',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 270000,
#   'price': 270000,
#   'priceMax': 275000,
#   'priceMin': 250000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'houseboat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': None,
#   'zindex': None},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 16,
#   'acornType': 16,
#   'areaName': 'London',
#   'bedsMax': 3,
#   'bedsMin': 3,
#   'branchId': 101641,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(249290).png',
#   'branchName': 'Winkworth - Kennington Sales',
#   'brandName': 'Winkworth',
#   'chainFree': False,
#   'companyId': 4040,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Ravensdon Street, Kennington, London SE11',
#   'furnishedState': '',
#   'groupId': 44,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '4AR',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58425076,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 3,
#   'numImages': 16,
#   'numRecepts': 2,
#   'outcode': 'SE11',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 1350000,
#   'price': 1350000,
#   'priceMax': 1400000,
#   'priceMin': 1300000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 719209},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 8169,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(249290).png',
#   'branchName': 'Winkworth - Dulwich',
#   'brandName': 'Winkworth',
#   'chainFree': False,
#   'companyId': 4040,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Hillsboro Road, East Dulwich, London SE22',
#   'furnishedState': '',
#   'groupId': 44,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '8QE',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58424849,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 12,
#   'numRecepts': 1,
#   'outcode': 'SE22',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 700000,
#   'price': 700000,
#   'priceMax': 700000,
#   'priceMin': 700000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'leasehold',
#   'zindex': 735798},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 17,
#   'acornType': 17,
#   'areaName': 'London',
#   'bedsMax': 1,
#   'bedsMin': 1,
#   'branchId': 58933,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(584439).png',
#   'branchName': 'Purplebricks, Head Office',
#   'brandName': 'Purplebricks',
#   'chainFree': False,
#   'companyId': 31628,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Herne Hill Road, Herne Hill SE24',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '0AR',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 45213795,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 1,
#   'numImages': 11,
#   'numRecepts': 1,
#   'outcode': 'SE24',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 440000,
#   'price': 440000,
#   'priceMax': 450000,
#   'priceMin': 425000,
#   'priceQualifier': 'guide_price',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 418797},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 15,
#   'acornType': 15,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 93947,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(687104).png',
#   'branchName': 'Moveli',
#   'brandName': 'Moveli',
#   'chainFree': True,
#   'companyId': 69787,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Willow Lodge, 195 Cedars Road, London SW4',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '0PU',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58424238,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 2,
#   'numImages': 14,
#   'numRecepts': 1,
#   'outcode': 'SW4',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 550000,
#   'price': 550000,
#   'priceMax': 550000,
#   'priceMin': 550000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '796',
#   'tenure': None,
#   'zindex': 670865},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 15,
#   'acornType': 15,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 104328,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(295280).png',
#   'branchName': 'Marsh & Parsons - Streatham Hill',
#   'brandName': 'Marsh & Parsons',
#   'chainFree': False,
#   'companyId': 7059,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'The High, Streatham High Road SW16',
#   'furnishedState': '',
#   'groupId': 10,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '1EY',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 56454597,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 9,
#   'numRecepts': 2,
#   'outcode': 'SW16',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 440000,
#   'price': 440000,
#   'priceMax': 450000,
#   'priceMin': 425000,
#   'priceQualifier': 'guide_price',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'leasehold',
#   'zindex': 392583},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 55,
#   'acornType': 55,
#   'areaName': 'London',
#   'bedsMax': 3,
#   'bedsMin': 3,
#   'branchId': 58933,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(584439).png',
#   'branchName': 'Purplebricks, Head Office',
#   'brandName': 'Purplebricks',
#   'chainFree': False,
#   'companyId': 31628,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Abbots Park, London SW2',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '3QZ',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58423971,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 3,
#   'numImages': 12,
#   'numRecepts': 2,
#   'outcode': 'SW2',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 350000,
#   'price': 350000,
#   'priceMax': 350000,
#   'priceMin': 350000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'leasehold',
#   'zindex': 368083},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 17,
#   'acornType': 17,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 61799,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(466896).png',
#   'branchName': 'Pedder - West Norwood',
#   'brandName': 'Pedder',
#   'chainFree': False,
#   'companyId': 29514,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Ullswater Road, West Norwood, London SE27',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '0AL',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58423947,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 2,
#   'numImages': 10,
#   'numRecepts': 1,
#   'outcode': 'SE27',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 650000,
#   'price': 650000,
#   'priceMax': 650000,
#   'priceMin': 650000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': None,
#   'zindex': 393301},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 4,
#   'bedsMin': 4,
#   'branchId': 14233,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(275279).png',
#   'branchName': 'Jacksons Estate Agents - Streatham',
#   'brandName': 'Jacksons Estate Agents',
#   'chainFree': False,
#   'companyId': 7064,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Amesbury Avenue, London SW2',
#   'furnishedState': '',
#   'groupId': 24,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '3AE',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58423662,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 4,
#   'numImages': 11,
#   'numRecepts': 1,
#   'outcode': 'SW2',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 975000,
#   'price': 975000,
#   'priceMax': 1000000,
#   'priceMin': 950000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': '',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 462693},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 14,
#   'acornType': 14,
#   'areaName': 'London',
#   'bedsMax': 3,
#   'bedsMin': 3,
#   'branchId': 58933,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(584439).png',
#   'branchName': 'Purplebricks, Head Office',
#   'brandName': 'Purplebricks',
#   'chainFree': False,
#   'companyId': 31628,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Iveley Road, Clapham SW4',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '0EW',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58423304,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 3,
#   'numImages': 11,
#   'numRecepts': 1,
#   'outcode': 'SW4',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 900000,
#   'price': 900000,
#   'priceMax': 900000,
#   'priceMin': 900000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 835527},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 6,
#   'bedsMin': 6,
#   'branchId': 115668,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(644074).png',
#   'branchName': 'Knight Frank - Dulwich Village Sales',
#   'brandName': 'Knight Frank',
#   'chainFree': False,
#   'companyId': 2182,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Lovelace Road, West Dulwich, London SE21',
#   'furnishedState': 'unfurnished',
#   'groupId': 94,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '8JR',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58421831,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 6,
#   'numImages': 21,
#   'numRecepts': 4,
#   'outcode': 'SE21',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 2250000,
#   'price': 2250000,
#   'priceMax': 2300000,
#   'priceMin': 2200000,
#   'priceQualifier': 'guide_price',
#   'propertyHighlight': '',
#   'propertyType': 'detached',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '4221',
#   'tenure': None,
#   'zindex': 1396455},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 16,
#   'acornType': 16,
#   'areaName': 'London',
#   'bedsMax': 4,
#   'bedsMin': 4,
#   'branchId': 6240,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(643976).png',
#   'branchName': 'Rampton Baseley',
#   'brandName': 'Rampton Baseley',
#   'chainFree': False,
#   'companyId': 3133,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Iveley Road, London SW4',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '0EN',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58421463,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 4,
#   'numImages': 13,
#   'numRecepts': 2,
#   'outcode': 'SW4',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 1400000,
#   'price': 1400000,
#   'priceMax': 1400000,
#   'priceMin': 1400000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': None},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': None,
#   'acornType': None,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 115075,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(706508).png',
#   'branchName': 'MyLondonHome Battersea',
#   'brandName': 'MyLondonHome',
#   'chainFree': False,
#   'companyId': 8191,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Three Riverlight Quay, Nine Elms SW11',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '8BE',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58421391,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 2,
#   'numImages': 16,
#   'numRecepts': 1,
#   'outcode': 'SW11',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 1300000,
#   'price': 1300000,
#   'priceMax': 1300000,
#   'priceMin': 1300000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '988',
#   'tenure': 'leasehold',
#   'zindex': None},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 14,
#   'acornType': 14,
#   'areaName': 'London',
#   'bedsMax': 3,
#   'bedsMin': 3,
#   'branchId': 104185,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(623201).png',
#   'branchName': 'Keller Williams London Bridge',
#   'brandName': 'Keller Williams',
#   'chainFree': False,
#   'companyId': 33518,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': '3 All Saints Close, Stockwell, London SW8',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '2PW',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58421382,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 3,
#   'numBeds': 3,
#   'numImages': 21,
#   'numRecepts': 2,
#   'outcode': 'SW8',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 1500000,
#   'price': 1500000,
#   'priceMax': 1500000,
#   'priceMin': 1500000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 1197398},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 17034,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(479408).png',
#   'branchName': 'Wooster & Stock',
#   'brandName': 'Wooster & Stock',
#   'chainFree': False,
#   'companyId': 8488,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Benhill Road, Camberwell SE5',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '7LZ',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58421284,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 28,
#   'numRecepts': 1,
#   'outcode': 'SE5',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 825000,
#   'price': 825000,
#   'priceMax': 850000,
#   'priceMin': 800000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'end_terrace',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '1002',
#   'tenure': None,
#   'zindex': 484043},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 54,
#   'acornType': 54,
#   'areaName': 'London',
#   'bedsMax': 1,
#   'bedsMin': 1,
#   'branchId': 1349,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(293928).png',
#   'branchName': 'Portico - Clapham',
#   'brandName': 'Portico',
#   'chainFree': True,
#   'companyId': 581,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Brandon Estate, London SE17',
#   'furnishedState': '',
#   'groupId': 69,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '3NN',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420999,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': None,
#   'numBeds': 1,
#   'numImages': 7,
#   'numRecepts': None,
#   'outcode': 'SE17',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 270000,
#   'price': 270000,
#   'priceMax': 275000,
#   'priceMin': 250000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'leasehold',
#   'zindex': 334239},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 73366,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(313962).png',
#   'branchName': 'Urban Village',
#   'brandName': 'Urban Village',
#   'chainFree': False,
#   'companyId': 40881,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Springhill Close, London SE5',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '8AJ',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420792,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 14,
#   'numRecepts': None,
#   'outcode': 'SE5',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 465000,
#   'price': 465000,
#   'priceMax': 475000,
#   'priceMin': 450000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': None,
#   'zindex': 459446},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 16,
#   'acornType': 16,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 16402,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(326710).png',
#   'branchName': 'James Pendleton, Clapham Common & Brixton Office',
#   'brandName': 'James Pendleton',
#   'chainFree': False,
#   'companyId': 1965,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'The Chase, Clapham, London SW4',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '0NP',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420138,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 11,
#   'numRecepts': 1,
#   'outcode': 'SW4',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 495000,
#   'price': 495000,
#   'priceMax': 500000,
#   'priceMin': 475000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'share_of_freehold',
#   'zindex': 663345},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 17,
#   'acornType': 17,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 32650,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(592983).png',
#   'branchName': 'Foxtons - Streatham',
#   'brandName': 'Foxtons',
#   'chainFree': False,
#   'companyId': 1370,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Knollys Road, Streatham, London SW16',
#   'furnishedState': '',
#   'groupId': None,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '2JU',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420124,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 1,
#   'numBeds': 2,
#   'numImages': 8,
#   'numRecepts': 1,
#   'outcode': 'SW16',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 350000,
#   'price': 350000,
#   'priceMax': 350000,
#   'priceMin': 350000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': None,
#   'zindex': 553429},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 14,
#   'acornType': 14,
#   'areaName': 'London',
#   'bedsMax': 4,
#   'bedsMin': 4,
#   'branchId': 56771,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(358974).png',
#   'branchName': 'Dexters - Clapham',
#   'brandName': 'Dexters',
#   'chainFree': False,
#   'companyId': 1096,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Caldervale Road, London SW4',
#   'furnishedState': '',
#   'groupId': 24,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '9LY',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420064,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 4,
#   'numImages': 7,
#   'numRecepts': 2,
#   'outcode': 'SW4',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 1499950,
#   'price': 1499950,
#   'priceMax': 1500000,
#   'priceMin': 1400000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': '',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '18837',
#   'tenure': 'freehold',
#   'zindex': 757103},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 46,
#   'acornType': 46,
#   'areaName': 'London',
#   'bedsMax': 2,
#   'bedsMin': 2,
#   'branchId': 3591,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(707660).png',
#   'branchName': 'Hamptons - Clapham Sales',
#   'brandName': 'Hamptons',
#   'chainFree': False,
#   'companyId': 1612,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Heather Close, London SW8',
#   'furnishedState': '',
#   'groupId': 8,
#   'hasEpc': False,
#   'hasFloorplan': True,
#   'incode': '3BS',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58420020,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 2,
#   'numImages': 9,
#   'numRecepts': 1,
#   'outcode': 'SW8',
#   'postalArea': 'SW',
#   'postTownName': 'London',
#   'priceActual': 615000,
#   'price': 615000,
#   'priceMax': 650000,
#   'priceMin': 600000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'flat',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'leasehold',
#   'zindex': 476391},
#  {'__typename': 'ListingAnalyticsTaxonomy',
#   'acorn': 20,
#   'acornType': 20,
#   'areaName': 'London',
#   'bedsMax': 3,
#   'bedsMin': 3,
#   'branchId': 80066,
#   'branchLogoUrl': 'https://st.zoocdn.com/zoopla_static_agent_logo_(701121).png',
#   'branchName': 'Acorn - Camberwell',
#   'brandName': 'Acorn',
#   'chainFree': True,
#   'companyId': 8143,
#   'countryCode': 'gb',
#   'countyAreaName': 'London',
#   'currencyCode': 'GBP',
#   'displayAddress': 'Canning Cross, London SE5',
#   'furnishedState': '',
#   'groupId': 25,
#   'hasEpc': True,
#   'hasFloorplan': True,
#   'incode': '8BH',
#   'isRetirementHome': False,
#   'isSharedOwnership': False,
#   'listingCondition': 'pre-owned',
#   'listingId': 58419984,
#   'listingsCategory': 'residential',
#   'listingStatus': 'for_sale',
#   'location': 'London',
#   'memberType': 'agent',
#   'numBaths': 2,
#   'numBeds': 3,
#   'numImages': 15,
#   'numRecepts': 1,
#   'outcode': 'SE5',
#   'postalArea': 'SE',
#   'postTownName': 'London',
#   'priceActual': 690000,
#   'price': 690000,
#   'priceMax': 700000,
#   'priceMin': 650000,
#   'priceQualifier': '',
#   'propertyHighlight': '',
#   'propertyType': 'terraced',
#   'regionName': 'London',
#   'section': 'for-sale',
#   'sizeSqFeet': '',
#   'tenure': 'freehold',
#   'zindex': 724818}]

# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.37'})
rows = []
house_urls = set()
total_pages = 0
#set min price, sort lowest first, go through all 400, -> set min price at around 400 page, go through all 400 ->s 

min_prices = ["50000", "300000", "350000", "400000", "450000", "500000", "550000", "600000", "650000", "750000", "900000", "1300000", "4250000"]
#min_prices = ["50000", "300000"]

for min_price in min_prices :

    for page in range(0,401):
        total_pages += 1
 

        #search_url = "https://www.zoopla.co.uk/for-sale/property/london/brixton/?include_sold=true&is_auction=false&is_retirement_home=false&is_shared_ownership=false&page_size=25&q=Brixton%2C%20London&radius=1&results_sort=newest_listings&search_source=refine" + "&pn" + str(page)
        #search_url = "https://www.zoopla.co.uk/for-sale/property/london/?include_sold=true&is_auction=false&is_retirement_home=false&is_shared_ownership=false&page_size=25&q=London&radius=0&results_sort=newest_listings&search_source=refine" + "&pn" + str(page)
        search_url = f"https://www.zoopla.co.uk/for-sale/property/london/?include_sold=true&is_auction=false&is_retirement_home=false&is_shared_ownership=false&price_min={min_price}&q=London&radius=0&results_sort=lowest_price&search_source=facets" + "&pn" + str(page)

        response = requests.get(search_url, headers=headers)
        #response = requests.get(search_url, headers={'User-Agent': 'Mozilla/5.0'})
        search_html = BeautifulSoup(response.text, 'html5lib')

        search_house_containers = search_html.find_all('div', class_='earci3d1 css-tk5q7b-Wrapper-ListingCard-StyledListingCard e2uk8e10')

        time.sleep(random.randint(1, 4))

        if search_house_containers != []:
            for container in search_house_containers:
                url_suffix = container.a['href'].split('?')[0]
                if len(url_suffix) == 27:
                    house_urls.update(["https://www.zoopla.co.uk" + url_suffix])
        else:
            print("No Houses on page")
            
        #print("house urls = " + house_urls)

for house_url in house_urls:
    
    try:
        house_response = requests.get(house_url, headers=headers)
        house_html = BeautifulSoup(house_response.text, 'html5lib')
        house_details = house_html.find('script', id='__NEXT_DATA__')

        details_dict = json.loads(house_details.text)

        specific_info = details_dict['props']['initialProps']['pageProps']['data']['listing']['adTargeting']

        rows.append(specific_info)

        time.sleep(random.randint(1, 3))
        #print("Next house")
    except:
        print("error on this one " + house_url)

# print("Next Page, finished page " + str(n_page))
# print(str(count) + " Houses on that page")



print('You scraped {} pages containing {} properties.'.format(total_pages, len(rows)))
# Out:
# No Houses on page
# No Houses on page
# No Houses on page
# You scraped 5213 pages containing 333 properties.

# %%
len(house_urls)
# Out:
# 333

# %%
test_set = set()

# %%
test_set
# Out:
# set()

# %%
test_set.update(['Hi'])

# %%
test_set
# Out:
# {'H', 'Hi', 'i'}

# %%
wholedf = pd.DataFrame(rows)

# %%
wholedf.columns
# Out:
# Index(['__typename', 'acorn', 'acornType', 'areaName', 'bedsMax', 'bedsMin',
#        'branchId', 'branchLogoUrl', 'branchName', 'brandName', 'chainFree',
#        'companyId', 'countryCode', 'countyAreaName', 'currencyCode',
#        'displayAddress', 'furnishedState', 'groupId', 'hasEpc', 'hasFloorplan',
#        'incode', 'isRetirementHome', 'isSharedOwnership', 'listingCondition',
#        'listingId', 'listingsCategory', 'listingStatus', 'location',
#        'memberType', 'numBaths', 'numBeds', 'numImages', 'numRecepts',
#        'outcode', 'postalArea', 'postTownName', 'priceActual', 'price',
#        'priceMax', 'priceMin', 'priceQualifier', 'propertyHighlight',
#        'propertyType', 'regionName', 'section', 'sizeSqFeet', 'tenure',
#        'zindex'],
#       dtype='object')

# %%
# dropped = wholedf.drop(['__typename', 'acorn', 'bedsMax', 'bedsMin', 'branchId','branchLogoUrl', 'branchName', 'brandName', 'chainFree',
#        'companyId', 'countryCode', 'countyAreaName', 'currencyCode',
#        'displayAddress', 'furnishedState', 'groupId', 'hasEpc', 'hasFloorplan',
#        'incode', 'isRetirementHome', 'isSharedOwnership', 'listingCondition', 'memberType'], axis=1)

dropped = dropped.drop(['priceQualifier', 'propertyHighlight', 'section', 'acornType', 'listingsCategory', 'location'], axis=1)

# %%
dropped.sort_values('price').tail(30)
# Out:
#                  areaName  listingId     listingStatus  numBaths  numBeds  \
# 48                 London   57928655  sale_under_offer       4.0      7.0
# 222                London   56237696  sale_under_offer       NaN      7.0
# 40                 London   58421720          for_sale       3.0      4.0
# 39                 London   56949872          for_sale       4.0      6.0
# 199  Kingston upon Thames   57870850          for_sale       6.0      8.0
# 213                London   53868621          for_sale       3.0      5.0
# 24   Cuffley, Potters Bar   57371566          for_sale       6.0      7.0
# 25                 London   58299718          for_sale       3.0      4.0
# 37                 London   58158140          for_sale       5.0      6.0
# 149                London   58020702          for_sale       3.0      4.0
# 59                 London   57213872          for_sale       3.0      3.0
# 147                London   53137574          for_sale       3.0      3.0
# 151                London   54905683          for_sale       3.0      6.0
# 139                London   58013794          for_sale       3.0      4.0
# 164                London   57607886          for_sale       4.0      5.0
# 245                London   57867025          for_sale       5.0      6.0
# 277                London   57827666          for_sale       3.0      4.0
# 118                London   56975700          for_sale       5.0      6.0
# 294                London   55231534          for_sale       3.0      4.0
# 172                London   56761134              sold       1.0      1.0
# 273                London   56949775          for_sale       4.0      6.0
# 177                London   58082645          for_sale       2.0      3.0
# 178                London   55284245          for_sale       3.0      6.0
# 78                 London   57147143          for_sale       3.0      3.0
# 77                 London   57867459              sold       5.0      6.0
# 72               Richmond   58099062          for_sale       3.0      4.0
# 189                London   57326035          for_sale       2.0      3.0
# 150                London   56635345  sale_under_offer       3.0      5.0
# 263                London   57683777              sold       NaN      5.0
# 264                London   57981724          for_sale       3.0      4.0
#
#      numImages  numRecepts outcode postalArea          postTownName  \
# 48          18         3.0    SW13         SW                London
# 222         12         NaN    SW15         SW                London
# 40           7         2.0      W8          W                London
# 39          25         2.0     NW8         NW                London
# 199         15         NaN     KT2         KT  Kingston upon Thames
# 213         11         1.0    SW1W         SW                London
# 24          41         5.0     EN6         EN           Potters Bar
# 25           8         2.0      W8          W                London
# 37          20         3.0     SW6         SW                London
# 149         22         2.0     SE1         SE                London
# 59          18         2.0     W11          W                London
# 147         23         NaN      W8          W                London
# 151         15         3.0      W6          W                London
# 139         18         4.0     NW3         NW                London
# 164         11         2.0      W2          W                London
# 245         25         1.0     NW8         NW                London
# 277          7         3.0      W2          W                London
# 118         12         2.0     NW8         NW                London
# 294         17         2.0      W2          W                London
# 172          7         1.0    SW1X         SW                London
# 273          9         1.0     NW8         NW                London
# 177         27         2.0     SE1         SE                London
# 178         14         NaN      W6          W                London
# 78          12         2.0     SW7         SW                London
# 77          15         3.0    SW15         SW                London
# 72          35         NaN    TW10         TW              Richmond
# 189         11         2.0     W11          W                London
# 150         13         3.0    SW13         SW                London
# 263         13         NaN    SW19         SW                London
# 264         28         NaN      W8          W                London
#
#      priceActual    price  priceMax  priceMin   propertyType  \
# 48       4250000  4250000   4250000   4250000  semi_detached
# 222      4250000  4250000   4250000   4250000       detached
# 40       4250000  4250000   4250000   4250000           flat
# 39       4250000  4250000   4250000   4250000           flat
# 199      4250000  4250000   4250000   4250000       detached
# 213      4250000  4250000   4250000   4250000  semi_detached
# 24       4250000  4250000   4250000   4250000       detached
# 25       4250000  4250000   4250000   4250000           flat
# 37       4250000  4250000   4250000   4250000  semi_detached
# 149      4250000  4250000   4250000   4250000           flat
# 59       4250000  4250000   4250000   4250000
# 147      4250000  4250000   4250000   4250000           flat
# 151      4250000  4250000   4250000   4250000    end_terrace
# 139      4250000  4250000   4250000   4250000       terraced
# 164      4250000  4250000   4250000   4250000       terraced
# 245      4250000  4250000   4250000   4250000           flat
# 277      4250000  4250000   4250000   4250000       terraced
# 118      4250000  4250000   4250000   4250000           flat
# 294      4250000  4250000   4250000   4250000           flat
# 172      4250000  4250000   4250000   4250000           flat
# 273      4250000  4250000   4250000   4250000           flat
# 177      4250000  4250000   4250000   4250000
# 178      4250000  4250000   4250000   4250000    end_terrace
# 78       4250000  4250000   4250000   4250000           flat
# 77       4250000  4250000   4250000   4250000       detached
# 72       4250000  4250000   4250000   4250000  semi_detached
# 189      4250000  4250000   4250000   4250000       terraced
# 150      4250000  4250000   4250000   4250000       terraced
# 263      4250000  4250000   4250000   4250000       detached
# 264      4250000  4250000   4250000   4250000       terraced
#
#              regionName sizeSqFeet             tenure     zindex
# 48               London                      freehold  2644503.0
# 222              London                      freehold  2289424.0
# 40               London                     leasehold  2971728.0
# 39               London       2332          leasehold  2908331.0
# 199              London                          None  1751334.0
# 213              London                      freehold  3312590.0
# 24      East of England                      freehold  2371554.0
# 25               London       2311           freehold  2971728.0
# 37               London                      freehold  3886479.0
# 149              London                          None   872160.0
# 59               London                          None  3555845.0
# 147              London                     leasehold  2599138.0
# 151              London                      freehold  3828976.0
# 139              London                      freehold        NaN
# 164              London                      freehold  4410498.0
# 245              London                          None  2908331.0
# 277              London       2302           freehold  3167045.0
# 118              London       2398               None  2908331.0
# 294              London       3055               None  3149907.0
# 172              London                     leasehold  2345469.0
# 273              London                     leasehold  2908331.0
# 177              London                          None   872160.0
# 178              London                          None  3828976.0
# 78               London       1853  share_of_freehold  4602004.0
# 77               London       6598               None  4356300.0
# 72   South East England       3724           freehold  1514452.0
# 189              London                      freehold  3555845.0
# 150              London                      freehold  3976974.0
# 263              London                      freehold  4849890.0
# 264              London       2500           freehold  2188993.0

# %%
test_set = set()

# %%
url_suffix = "/433456789/"


test_set.update(["https://www.zoopla.co.uk" + url_suffix])

# %%
test_set
# Out:
# {'https://www.zoopla.co.uk/123456789',
#  'https://www.zoopla.co.uk/223456789',
#  'https://www.zoopla.co.uk/323456789',
#  'https://www.zoopla.co.uk/333456789',
#  'https://www.zoopla.co.uk/333456789/',
#  'https://www.zoopla.co.uk/433456789/'}
